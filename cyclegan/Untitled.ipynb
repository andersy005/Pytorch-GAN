# %%
import os
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import pathlib

# %%
H2Z = pathlib.Path('datasets/horse2zebra/')

# %%
ls {H2Z}
# Out:
# testA/  testB/  trainA/  trainB/

# %%
import torch
from torchvision import datasets
from torchvision import transforms

# %%
class Config(object):
    def __init__(self, image_size, domain_A_path, domain_B_path):
        self.image_size = image_size
        self.domain_A_path = domain_A_path
        self.domain_B_path = domain_B_path
config = Config(64, None, None)

# %%
def get_loader(config):
    
    """Builds and returns Dataloader for Horse2zebra dataset."""
    
    
    ])

# %%
transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Scale(64),
        transforms.ToTensor(),
        #transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
class DomainDataset(Dataset):
    """Domain A dataset """
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.files = os.listdir(root_dir)
        
    def __len__(self):
        return len(os.listdir(self.root_dir))
    
    def __getitem__(self, idx):
        img_name = self.root_dir/self.files[idx]
        image = io.imread(img_name)
        if self.transform:
            image = self.transform(image)
            
        return image

# %%
pathA / os.listdir(pathA)[1]
# Out:
# PosixPath('datasets/horse2zebra/trainA/n02381460_4597.jpg')

# %%
pathA = H2Z/'trainA'
pathB = H2Z/'trainB'
DomainA = DomainDataset(pathA, transform=transform)
DomainB = DomainDataset(pathB)

# %%
len(DomainA), len(DomainB)
# Out:
# (1067, 1334)

# %%
for i in range(3):
    sample = DomainA[i]
    plt.imshow(sample)
    plt.show()
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-7b5eded826b7> in <module>()
#       1 for i in range(3):
#       2     sample = DomainA[i]
# ----> 3     plt.imshow(sample)
#       4     plt.show()
#       5
#
# ~/opt/miniconda3/envs/deeplearning/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3099                         filternorm=filternorm, filterrad=filterrad,
#    3100                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3101                         **kwargs)
#    3102     finally:
#    3103         ax._hold = washold
#
# ~/opt/miniconda3/envs/deeplearning/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
a = DomainA[0]

# %%
a.numpy()
# Out:
# array([[[-0.17647058, -0.36470586, -0.46666664, ..., -0.41960782,
#          -0.41176468, -0.3333333 ],
#         [-0.2235294 , -0.44313723, -0.5058824 , ..., -0.42745095,
#          -0.42745095, -0.38823527],
#         [-0.3490196 , -0.47450978, -0.5137255 , ..., -0.5137255 ,
#          -0.46666664, -0.46666664],
#         ...,
#         [-0.10588235, -0.14509803, -0.12156862, ...,  0.0196079 ,
#           0.0196079 , -0.03529412],
#         [-0.17647058, -0.12941176, -0.01960784, ...,  0.04313731,
#           0.03529418,  0.00392163],
#         [-0.09803921, -0.0745098 ,  0.00392163, ..., -0.05098039,
#           0.01176476, -0.01960784]],
#
#        [[-0.09803921, -0.26274508, -0.38823527, ..., -0.41176468,
#          -0.372549  , -0.32549018],
#         [-0.19999999, -0.38039213, -0.4588235 , ..., -0.38823527,
#          -0.38039213, -0.3333333 ],
#         [-0.31764704, -0.45098037, -0.4980392 , ..., -0.45098037,
#          -0.41176468, -0.41960782],
#         ...,
# ...

# %%
for i in range(3):
    sample = DomainB[i]
    plt.imshow(sample)
    plt.show()
    
plt.show()
